# %%
#16th DEC'22

#Create a Jupyter notebook as a tutorial for introduction to programming
#Should contain the following cells
#	1. Markdown : Heading with text "Introduction to Programming'
#	2. Text data with bold,italic text and bullet points 
#	3. Images examples
#	4. Web links
#	5. Youtube videos atleast two in the jupyter notebook

# %%
#1. Markdown : Heading with text "Introduction to Programming'
#2. Text data with bold,italic text and bullet points

# %% [markdown]
# # Introduction to Python Programming

# %% [markdown]
# **Sol_1 & 2**
# 1. *For first heading we are using*  **#**  *in markdown cell*.<br>
# 2. *For second heading we are using* **##** *in markdown cell*.<br>
# 3. *For third heading we are using* **###** *in markdown cell*.<br>
# 4. *For fourth heading we are using* **####** *in markdown cell*.<br>
# 5. *For making data in bold we use double star **Bold** and for italic we need to use single star *Italic* & for bullets give bullet mark and leave two spaces after that.

# %%
#3. Images examples

# %% [markdown]
# **Sol 3**
# We can insert images in two ways
# 1.  From edit option we need to select insert imgae.
# 2.  From google also we can insert the image kindly refer the below code.

# %% [markdown]
# -  _**Images Examples from files**_

# %% [markdown]
# ![photo-1538370965046-79c0d6907d47.jpeg](attachment:photo-1538370965046-79c0d6907d47.jpeg)

# %%
# %%HTML
# <iframe width="600" height="315"
# src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png">
# </iframe>
# # How to do zoom out ?
# Out:
# <iframe width="600" height="315"
# src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png">
# </iframe>
# # How to do zoom out ?

# %% [markdown]
# **Sol 4**
# Some useful Web links for learning python
#
# This is [Byte of Python](https://www.ibiblio.org/swaroopch/byteofpython/files/120/byteofpython_120.pdf)
#
# This is [Python Tutorial](https://www.w3schools.com/python/)

# %%
#5. Youtube videos atleast two in the jupyter notebook

# %%
# %%HTML
# <iframe width="500" height="415"
# src="https://www.youtube.com/embed/yEIc9z-Ad3k?autoplay=0&mute=0">
# </iframe>
# <h2> Another video </h2>
# <iframe width="600" height="315"
# src="https://www.youtube.com/embed/yEIc9z-Ad3k?autoplay=0&mute=0">
# </iframe>
# Out:
# <iframe width="500" height="415"
# src="https://www.youtube.com/embed/yEIc9z-Ad3k?autoplay=0&mute=0">
# </iframe>
# <h2> Another video </h2>
# <iframe width="600" height="315"
# src="https://www.youtube.com/embed/yEIc9z-Ad3k?autoplay=0&mute=0">
# </iframe>

# %% [markdown]
# **Some magic commants**

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...
