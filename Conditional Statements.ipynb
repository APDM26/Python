# %% [markdown]
# # 5 Class Ekeeda 24th Dec'22 Conditional Statements

# %% [markdown]
# # Conditional Statements without using nested If

# %%
# Railway Ticketing System--------------------- Assignment 
'''
Doubts
# Q.how to avoid previous date selection?
0. Enter user Id & password for LogIn in IRCTC if not then do registerartion 
1.Select your journey date & confirm your arrival & departure  if not select the correct journey date select corrrect one.
2.Create a list of avaialble trains & category of seats.
3.Check for the availabilty of seats based on category 
4.Check user balance amount for booking the ticket 
'''
# Out:
# '\nDoubts\n# Q.how to avoid previous date selection?\n0. Enter user Id & password for LogIn in IRCTC if not then do registerartion \n1.Select your journey date & confirm your arrival & departure  if not select the correct journey date select corrrect one.\n2.Create a list of avaialble trains & category of seats.\n3.Check for the availabilty of seats based on category \n4.Check user balance amount for booking the ticket \n'

# %%
#Starting Code

journeydate=["26/12/22","27/12/22","28/12/22","29/12/22","30/12/22"]
arrival=["Prayagraj","Varanasi","Ayodhya","Chitrakoot","Mathura"]
Departure=["Mathura","Ayodya","Varanasi","Prayagraj","Chitrakoot"]
train1=["Rajadhani","Vandebharat","Doronto"]
category=["Ac1","Ac2"]
seats = 10
ticket = 1000
user_balance = 500


# Step 0: User ID & Password
# The tracking is to track where the currect user is 
tracking = "Start"
print("Namastey , Welcome to IRCTC")

print("Kinldy enter your user ID & Password")

print("Enter your user name")
user = input()
print("Enter your password")
password = input()

if user == "Deeksha" and password == "Deek@123":
    print("user Id & password enterd correctly , Please proceed for booking")
    tracking ="User Verified"
else:
    print("Sorry you are not a registered member do Sinup or enter correct login details")
print("*"*50)
#Step 1
if tracking =="User Verified":
    print("Select your journey date")
    
    print(journeydate)
    print("Select the journey date in number from 0 to 5")
    print("Select only number")
    Journey_Date = int(input())
    if Journey_Date < len(journeydate):
        print("Hey you have choosed your journey date",journeydate[Journey_Date])
        tracking = "Date_Selected"
    else:
        print("We are not taking booking for your selected date")
        print("please select a number less than or equal to : ",len(journeydate)-1)
        Journey_Dateourney_Date = input()
        print("The selected date is",journeydate[Journey_Date])
        tracking = "Date_Selected"
else:
    print("Please go back to enter correct user Id and password")
print("*"*50)
#step 2

if tracking == "Date_Selected":
    print("Select your Departure Station")
    print(Departure)
    print("Select any any number from 0 to 4")
    Dep = int(input())
    if Dep < len(Departure):
        print("Your Departure destination is:",Departure[Dep])
        tracking = 'Departure_Selected'
    else:
        print("You entered wrong departure station, please enter <",len(list)-1)
        Dep = int(input())
        print("Your Departure destination is:",Departure[Dep])
        tracking = 'Departure_Selected'
else:
    print("Go back to select Date Selcted")
print("*"*50)

# Step3

if tracking =='Departure_Selected':
    print("Select your Arriaval Station")
    print(arrival)
    print("Select any any number from 0 to 4")
    Arr = int(input())
    if Arr < len(arrival):
        print("Your Departure destination is:",arrival[Arr])
        tracking = 'Arrival_Selected'
    else:
        print("You entered wrong departure station, please enter <",len(list)-1)
        Dep = int(input())
        print("Your Departure destination is:",arrival[Arr])
        tracking = 'Arrival_Selected'
else:
    print("Go back to select Departure")
print("*"*50)


dummy= {}
for date in journeydate:
    dummy[date]={}
    for trn in train1:
        dummy[date][trn]=category

# Step 4
if tracking =='Arrival_Selected':
    print("Please select your train & category from given list",dummy)
   
    select_train=input()
    if select_train in dummy[journeydate[Journey_Date]].keys():
        print("You have selected the correct date the available train is "\
              ,select_train)
        print("For selecting class please select 0 or 1:")
        seat =int(input())
        print("you have selected class:",dummy[journeydate[Journey_Date]][select_train][seat])
        tracking ="Train Selected"
    else:
        print("Train not available")

print("*"*50)
#Step 5
if tracking =="Train Selected":
    dummy1= {}
    for cls in category:
        dummy1[cls]= seats
    print("As you have selected ",dummy[journeydate[Journey_Date]][select_train][seat])
    print("The avaialbe seats are: ",dummy1[dummy[journeydate[Journey_Date]][select_train][seat]])
    cl_seat= dummy1[dummy[journeydate[Journey_Date]][select_train][seat]]
    choice = int(input())
    if choice < cl_seat:
        print("You are alloted with the seat number",choice)
        print("Now avaialbe seats are :",cl_seat-choice)
        tracking ='Seat_alloted'
    else:
        print("Plesae enter correct number")
print("*"*50)
#Step 6 
if tracking =='Seat_alloted':
    if ticket < user_balance:
        print("You have successfully booked your ticket: HAPPY JOURNEY")
        tracking ='ticket_Booked'
    else:
        add_amount = ticket - user_balance
        update=add_amount+user_balance
        print("Amount updated to pocket book your ticket")
        if update >=ticket:
            print("You have successfully booked your ticket: HAPPY JOURNEY")
        else:
            ("SO SORRY")
        tracking ='ticket_Booked'
print("*"*100)
# Out:
# Namastey , Welcome to IRCTC
# Kinldy enter your user ID & Password
# Enter your user name
# Deeksha
# Enter your password
# Deek@123
# user Id & password enterd correctly , Please proceed for booking
# **************************************************
# Select your journey date
# ['26/12/22', '27/12/22', '28/12/22', '29/12/22', '30/12/22']
# Select the journey date in number from 0 to 5
# Select only number
# 2
# Hey you have choosed your journey date 28/12/22
# **************************************************
# Select your Departure Station
# ['Mathura', 'Ayodya', 'Varanasi', 'Prayagraj', 'Chitrakoot']
# Select any any number from 0 to 4
# 2
# Your Departure destination is: Varanasi
# **************************************************
# Select your Arriaval Station
# ['Prayagraj', 'Varanasi', 'Ayodhya', 'Chitrakoot', 'Mathura']
# Select any any number from 0 to 4
# 2
# Your Departure destination is: Ayodhya
# **************************************************
# ...
